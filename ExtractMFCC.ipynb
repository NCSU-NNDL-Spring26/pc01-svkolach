# %% [markdown]
# # Extract MFCC Features
#
# Mel‑Frequency Cepstral Coefficients (MFCCs) are one of the most widely used features in audio and speech processing. They give you a compact, meaningful summary of the timbre or spectral shape of a sound.
#
# For our use case, we will window our data and extract MFCCs for each window, and save them as features that will be used to train a classifier.

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.13/site-packages (0.11.0)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.13/site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.13/site-packages (from librosa) (0.63.1)
# Requirement already satisfied: numpy>=1.22.3 in /opt/conda/lib/python3.13/site-packages (from librosa) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.13/site-packages (from librosa) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /opt/conda/lib/python3.13/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.13/site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.13/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.13/site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /opt/conda/lib/python3.13/site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.13/site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /opt/conda/lib/python3.13/site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /opt/conda/lib/python3.13/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.13/site-packages (from librosa) (1.1.2)
# Requirement already satisfied: standard-aifc in /opt/conda/lib/python3.13/site-packages (from librosa) (3.13.0)
# Requirement already satisfied: standard-sunau in /opt/conda/lib/python3.13/site-packages (from librosa) (3.13.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa) (26.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /opt/conda/lib/python3.13/site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.13/site-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.13/site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/conda/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.13/site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: standard-chunk in /opt/conda/lib/python3.13/site-packages (from standard-aifc->librosa) (3.13.0)
# Requirement already satisfied: audioop-lts in /opt/conda/lib/python3.13/site-packages (from standard-aifc->librosa) (0.2.2)

# %% [markdown]
# We begin by loading the necessary packages and setting the necessary parameter variables.

# %%
import numpy as np
import os
import helperFncs as hf
import matplotlib.pyplot as plt
from scipy.io.wavfile import write as wav_write
import importlib
import librosa
from scipy import stats

# Directory path to the data
FOLDER_IN = '/home/jovyan/Data/Train/'
FOLDER_OUT_TRAIN = '/home/jovyan/Data/Post_MFCC/Train/'
FOLDER_OUT_VAL = '/home/jovyan/Data/Post_MFCC/Val/'

# Mapping of label indices to their corresponding class names
labelList = {0: 'Speech', 1: 'Cough', 2: 'Non-Verbal', 3: 'Other'}

# Specifying a window size, step size
windowSize = 1 # secconds
stepSize = 0.5 # seconds
nMFCC = 32 # Number of MFCC coefficients to extract

# %% [markdown]
# Splitting the files into training and validation.

# %%
# Get a sorted list of all .h5 files in the input directory
fileList = sorted([f for f in os.listdir(FOLDER_IN) if f.endswith('.h5')])

# Splitting it into a training set and a validation set (last 6 files for validation).
# Assuming that they are in arbitrary order to begin with.
fileListTrain = fileList[:-6]
fileListVal = fileList[-6:]

# %% [markdown]
# Defining our main function for processing the data.

# %%
def extractMFCC(fileList, folderOut):
    for fileName in fileList:
        # Load the selected .h5 file into a nested dictionary
        file_path = os.path.join(FOLDER_IN, fileName)
        data = hf.h5_to_dict(file_path)

        print(f"... Processing: {fileName}")

        # Extract relevant data from the loaded dictionary
        audioSamplingRate = data['audio_sample_rate'] # Sampling rate of the audio signal
        audioData = data['audio_data'] # Audio signal data
        labelSamplingRate = data['label_sample_rate'] # Sampling rate of the labels
        labels = data['label'] # Label data corresponding to the audio signal

        # Convert window/step from seconds to samples
        audio_win_len = int(windowSize * audioSamplingRate)
        audio_hop_len = int(stepSize * audioSamplingRate)
        label_win_len = int(windowSize * labelSamplingRate)
        label_hop_len = int(stepSize * labelSamplingRate)

        # Determine the number of windows we can extract from both audio and labels
        n_audio_windows = (len(audioData) - audio_win_len) // audio_hop_len + 1
        n_label_windows = (len(labels) - label_win_len) // label_hop_len + 1
        n_windows = min(n_audio_windows, n_label_windows)

        mfcc_samples = []
        label_samples = []
        middle_time = []
        data_mfcc = {}

        # Slide over audioData and labels together and compute MFCC per window
        for i in range(n_windows):
            audio_start = i * audio_hop_len
            label_start = i * label_hop_len

            segment_audio = audioData[audio_start:audio_start + audio_win_len]
            segment_label = labels[label_start:label_start + label_win_len]

            mfcc = librosa.feature.mfcc(
                y=segment_audio.astype(float),
                sr=audioSamplingRate,
                n_mfcc=nMFCC,
                n_fft=audio_win_len,
                hop_length=audio_hop_len,
                center=False
            )
            # Store the MFCC for this segment
            mfcc_samples.append(mfcc)

            # Store the mode of this segment
            mode_label = stats.mode(segment_label, axis=None)
            mode_label = mode_label.mode
            label_samples.append(mode_label)
            
            # Store the middle time of this window in seconds
            middle_time.append((audio_start + audio_win_len/2.0)/audioSamplingRate)

        # Convert lists to numpy arrays and save to a new .h5 file
        data_mfcc['mfcc'] = np.stack(mfcc_samples, axis=0).squeeze(-1)
        data_mfcc['labels'] = np.array(label_samples)
        data_mfcc['middle_time'] = np.array(middle_time)

        outPath = os.path.join(folderOut, os.path.splitext(fileName)[0] + '.h5')
        hf.write_h5(outPath, data_mfcc)
        print(f"... Saved MFCC data to: {outPath}")

# %% [markdown]
# Processing and storing the training and validation sets.

# %%
# Extract MFCC features for both training and validation sets
print('Processing Training Set')
extractMFCC(fileListTrain, FOLDER_OUT_TRAIN)
print('Processing Validation Set')
extractMFCC(fileListVal, FOLDER_OUT_VAL)
# Out:
# Processing Training Set
# ... Processing: s01_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s01_trial1.h5
# ... Processing: s01_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s01_trial2.h5
# ... Processing: s01_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s01_trial3.h5
# ... Processing: s02_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s02_trial1.h5
# ... Processing: s02_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s02_trial2.h5
# ... Processing: s02_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s02_trial3.h5
# ... Processing: s03_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s03_trial1.h5
# ... Processing: s03_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s03_trial2.h5
# ... Processing: s03_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s03_trial3.h5
# ... Processing: s04_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s04_trial1.h5
# ... Processing: s04_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s04_trial2.h5
# ... Processing: s04_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s04_trial3.h5
# ... Processing: s05_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s05_trial1.h5
# ... Processing: s05_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s05_trial2.h5
# ... Processing: s05_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s05_trial3.h5
# ... Processing: s06_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s06_trial1.h5
# ... Processing: s06_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s06_trial2.h5
# ... Processing: s06_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s06_trial3.h5
# ... Processing: s07_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s07_trial1.h5
# ... Processing: s07_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s07_trial2.h5
# ... Processing: s07_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s07_trial3.h5
# ... Processing: s08_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s08_trial1.h5
# ... Processing: s08_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s08_trial2.h5
# ... Processing: s08_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Train/s08_trial3.h5
# Processing Validation Set
# ... Processing: s09_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Val/s09_trial1.h5
# ... Processing: s09_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Val/s09_trial2.h5
# ... Processing: s09_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Val/s09_trial3.h5
# ... Processing: s10_trial1.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Val/s10_trial1.h5
# ... Processing: s10_trial2.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Val/s10_trial2.h5
# ... Processing: s10_trial3.h5
# ... Saved MFCC data to: /home/jovyan/Data/Post_MFCC/Val/s10_trial3.h5
